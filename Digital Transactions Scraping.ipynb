# %%
import pandas as pd
import numpy as np
import bs4 as bs
import urllib.request

# %%
source = urllib.request.urlopen('http://www.digitaltransactions.net/buyers-guide/?wpbdpview=all-listings').read()

# %%
soup = bs.BeautifulSoup(source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://www.digitaltransactions.net/xmlrpc.php" rel="pingback"/>
#   <title>
#    Buyer’s Guide – Digital Transactions
#   </title>
#   <meta content="Buyer’s Guide - Digital Transactions" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="" property="og:description"/>
#   <meta content="http://www.digitaltransactions.net/buyers-guide/" property="og:url"/>
#   <meta content="Digital Transactions" property="og:site_name"/>
#   <style data-type="vc_shortcodes-custom-css">
#    .vc_custom_1555696222944{margin-bottom: 0px !important;padding-bottom: 10px !important;}
#   </style>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//use.fontawesome.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
# ...

# %%
list(soup.children)
# Out:
# ['html',
# ...

# %%
html = list(soup.children)[1]

# %%
list(html.children)
# Out:
# [<head><meta charset="utf-8"/><link href="http://gmpg.org/xfn/11" rel="profile"/><link href="http://www.digitaltransactions.net/xmlrpc.php" rel="pingback"/><title>Buyer’s Guide – Digital Transactions</title><meta content="Buyer’s Guide - Digital Transactions" property="og:title"/><meta content="article" property="og:type"/><meta content="" property="og:description"/><meta content="http://www.digitaltransactions.net/buyers-guide/" property="og:url"/><meta content="Digital Transactions" property="og:site_name"/><style data-type="vc_shortcodes-custom-css">.vc_custom_1555696222944{margin-bottom: 0px !important;padding-bottom: 10px !important;}</style><link href="//fonts.googleapis.com" rel="dns-prefetch"/><link href="//use.fontawesome.com" rel="dns-prefetch"/><link href="//s.w.org" rel="dns-prefetch"/><link href="http://www.digitaltransactions.net/events/?ical=1" rel="alternate" title="Digital Transactions » iCal Feed" type="text/calendar"/><link href="http://www.digitaltransactions.net/
# ...

# %%
body = list(html.children)[1]

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\n <head>\n  <meta charset="utf-8"/>\n  <link href="http://gmpg.org/xfn/11" rel="profile"/>\n  <link href="http://www.digitaltransactions.net/xmlrpc.php" rel="pingback"/>\n  <title>\n   Buyer’s Guide – Digital Transactions\n  </title>\n  <meta content="Buyer’s Guide - Digital Transactions" property="og:title"/>\n  <meta content="article" property="og:type"/>\n  <meta content="" property="og:description"/>\n  <meta content="http://www.digitaltransactions.net/buyers-guide/" property="og:url"/>\n  <meta content="Digital Transactions" property="og:site_name"/>\n  <style data-type="vc_shortcodes-custom-css">\n   .vc_custom_1555696222944{margin-bottom: 0px !important;padding-bottom: 10px !important;}\n  </style>\n  <link href="//fonts.googleapis.com" rel="dns-prefetch"/>\n  <link href="//use.fontawesome.com" rel="dns-prefetch"/>\n  <link href="//s.w.org" rel="dns-prefetch"/>\n  <link href="http://www.digitaltransactions.ne
# ...

# %%
soup.find_all(class_='field-label')
# Out:
# [<span class="field-label">Business Name:</span>,
#  <span class="field-label">Category:</span>,
#  <span class="field-label">Business Address:</span>,
#  <span class="field-label">City:</span>,
#  <span class="field-label">State:</span>,
#  <span class="field-label">ZIP Code:</span>,
#  <span class="field-label">Country:</span>,
#  <span class="field-label">Business Phone Number:</span>,
#  <span class="field-label">Business Website Address:</span>,
#  <span class="field-label">About this listing:</span>,
#  <span class="field-label">Business Name:</span>,
#  <span class="field-label">Category:</span>,
#  <span class="field-label">Business Address:</span>,
#  <span class="field-label">City:</span>,
#  <span class="field-label">State:</span>,
#  <span class="field-label">ZIP Code:</span>,
#  <span class="field-label">Country:</span>,
#  <span class="field-label">Business Phone Number:</span>,
#  <span class="field-label">Business Website Address:</span>,
# ...

# %%
stuff = soup.find_all(class_='listing-details')

# %%
stuff
# Out:
# [<div class="listing-details"><div class="wpbdp-field-display wpbdp-field wpbdp-field-value field-display field-value wpbdp-field-business_name wpbdp-field-title wpbdp-field-type-textfield wpbdp-field-association-title"><span class="field-label">Business Name:</span> <span class="value"><a href="http://www.digitaltransactions.net/buyers-guide/29655/accel/" target="_self">Accel</a></span></div><div class="wpbdp-field-display wpbdp-field wpbdp-field-value field-display field-value wpbdp-field-category wpbdp-field-category wpbdp-field-type-select wpbdp-field-association-category"><span class="field-label">Category:</span> <span class="value"><a href="http://www.digitaltransactions.net/buyers-guide/wpbdp_category/cardless-atm-program-mobile/" rel="tag">Cardless ATM Program (Mobile)</a>, <a href="http://www.digitaltransactions.net/buyers-guide/wpbdp_category/networks/" rel="tag">Networks</a></span></div><div class="wpbdp-field-display wpbdp-field wpbdp-field-value field-display field-valu
# ...

# %%
stuff[0].find_all( class_='value')[0].get_text()
# Out:
# 'Accel'
